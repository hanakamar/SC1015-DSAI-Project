# %% [markdown]
# # Data Preparation and Cleaning
# ---

# %%
# Basic Libraries
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt # we only need pyplot
sb.set() # set the default Seaborn style for graphics
from scipy.stats import zscore

# %%
fashiondata = pd.read_csv('fashiondata.csv')
fashiondata.head()
# Out:
#                            UserId  Followings  Followers  MediaCount  \
# 0   1171579752855683619_212070047       518.0     9840.0         541
# 1   1171594777274371222_176762322      7333.0     2300.0         272
# 2   1171407552643586413_581125501       131.0      605.0         106
# 3   1171407552643586413_581125501       131.0      605.0         106
# 4  1171508187966229230_2797323089       132.0      456.0          56
#
#      BrandName BrandCategory  \
# 0  abercrombie   High street
# 1  abercrombie   High street
# 2  abercrombie   High street
# 3  abercrombie   High street
# 4  abercrombie   High street
#
#                                             Hashtags  \
# 0  beautiful, summer, fashion, love, cute, food, ...
# 1  teen, model, brunette, selfie, hollister, snap...
# 2  alexandani, cute, llbean, beanboots, anthropol...
# 3  alexandani, cute, llbean, beanboots, anthropol...
# 4  abercrombieandfitch, shopping, love, hollister...
#
#                                              Caption  \
# 0    We were born to be REAL, not to be perfect. ...
# 1    Gotta run, but first, let me take selfie. Me...
# 2                        dress to impress\U0001f457
# 3                        dress to impress\U0001f457
# 4    #love #shopping #shoppen #hollister #abercro...
#
#                                               ImgURL  Likes  ...  \
# 0  https://scontent.cdninstagram.com/t51.2885-15/...     97  ...
# 1  https://scontent.cdninstagram.com/t51.2885-15/...     94  ...
# 2  https://scontent.cdninstagram.com/t51.2885-15/...     91  ...
# 3  https://scontent.cdninstagram.com/t51.2885-15/...     94  ...
# 4  https://scontent.cdninstagram.com/t51.2885-15/...      9  ...
#
#    NumberOfPeople  NumberOfFashionProduct     Anger  Contempt   Disgust  \
# 0        0.931486                 3.42211  0.083862  0.015089  0.000583
# 1        0.466329                 2.91971  0.000000  0.000000  0.000000
# 2        1.116500                 4.69096  0.000000  0.000000  0.000000
# 3        1.116500                 4.69096  0.000000  0.000000  0.000000
# 4        0.393063                 1.45586  0.000000  0.000000  0.000000
#
#        Fear  Happiness   Neutral   Sadness  Surprise
# 0  0.000026   0.000017  0.890586  0.009657  0.000181
# 1  0.000000   0.000000  0.000000  0.000000  0.000000
# 2  0.000000   0.000000  0.000000  0.000000  0.000000
# 3  0.000000   0.000000  0.000000  0.000000  0.000000
# 4  0.000000   0.000000  0.000000  0.000000  0.000000
#
# [5 rows x 33 columns]

# %%
fashiondata.dtypes
# Out:
# UserId                     object
# Followings                float64
# Followers                 float64
# MediaCount                  int64
# BrandName                  object
# BrandCategory              object
# Hashtags                   object
# Caption                    object
# ImgURL                     object
# Likes                       int64
# Comments                    int64
# CreationTime                int64
# Link                       object
# Selfie                    float64
# BodySnap                  float64
# Marketing                 float64
# ProductOnly               float64
# NonFashion                float64
# Face                      float64
# Logo                      float64
# BrandLogo                 float64
# Smile                     float64
# Outdoor                   float64
# NumberOfPeople            float64
# NumberOfFashionProduct    float64
# Anger                     float64
# Contempt                  float64
# Disgust                   float64
# Fear                      float64
# Happiness                 float64
# Neutral                   float64
# Sadness                   float64
# Surprise                  float64
# dtype: object

# %%
fashiondata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24752 entries, 0 to 24751
# Data columns (total 33 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   UserId                  24752 non-null  object
#  1   Followings              24752 non-null  float64
#  2   Followers               24752 non-null  float64
#  3   MediaCount              24752 non-null  int64
#  4   BrandName               24752 non-null  object
#  5   BrandCategory           24752 non-null  object
#  6   Hashtags                24606 non-null  object
#  7   Caption                 24717 non-null  object
#  8   ImgURL                  24752 non-null  object
#  9   Likes                   24752 non-null  int64
#  10  Comments                24752 non-null  int64
#  11  CreationTime            24752 non-null  int64
#  12  Link                    24752 non-null  object
#  13  Selfie                  24752 non-null  float64
#  14  BodySnap                24752 non-null  float64
#  15  Marketing               24752 non-null  float64
#  16  ProductOnly             24752 non-null  float64
#  17  NonFashion              24752 non-null  float64
#  18  Face                    24752 non-null  float64
#  19  Logo                    24752 non-null  float64
#  20  BrandLogo               24752 non-null  float64
#  21  Smile                   24752 non-null  float64
#  22  Outdoor                 24752 non-null  float64
#  23  NumberOfPeople          24752 non-null  float64
#  24  NumberOfFashionProduct  24752 non-null  float64
#  25  Anger                   24752 non-null  float64
#  26  Contempt                24752 non-null  float64
#  27  Disgust                 24752 non-null  float64
#  28  Fear                    24752 non-null  float64
#  29  Happiness               24752 non-null  float64
#  30  Neutral                 24752 non-null  float64
#  31  Sadness                 24752 non-null  float64
#  32  Surprise                24752 non-null  float64
# dtypes: float64(22), int64(4), object(7)
# memory usage: 6.2+ MB

# %% [markdown]
# ### Sanity check for duplicates & missing values

# %%
duplicate_rows = fashiondata[fashiondata.duplicated(keep=False)]
print("Duplicate rows:")
print(duplicate_rows)
# Out:
# Duplicate rows:
#                                UserId  Followings  Followers  MediaCount  \
# 100    1171299198127266963_2560516238       248.0      164.0         232
# 101    1171299198127266963_2560516238       248.0      164.0         232
# 120     1171231788214163629_193097469       451.0     4365.0         485
# 121     1171231788214163629_193097469       451.0     4365.0         485
# 529    1171022589527811636_2083414312      4998.0     4211.0        1293
# ...                               ...         ...        ...         ...
# 24742  1171578577234348127_1601300177      7495.0     4224.0        5558
# 24744  1171578445549979740_1601300177      7495.0     4224.0        5558
# 24745  1171578445549979740_1601300177      7495.0     4224.0        5558
# 24749  1171566525099211846_1433754542       209.0     8737.0       46254
# 24750  1171566525099211846_1433754542       209.0     8737.0       46254
#
#          BrandName BrandCategory  \
# 100    abercrombie   High street
# 101    abercrombie   High street
# 120    abercrombie   High street
# 121    abercrombie   High street
# 529    acnestudios      Designer
# ...            ...           ...
# 24742         zara   High street
# 24744         zara   High street
# 24745         zara   High street
# 24749         zara   High street
# 24750         zara   High street
#
#                                                 Hashtags  \
# 100    summer, fashion, love, dustyrose, trend, blogg...
# 101    summer, fashion, love, dustyrose, trend, blogg...
# 120    fashion, urbanoutfitters, nordstorm, nastygal,...
# 121    fashion, urbanoutfitters, nordstorm, nastygal,...
# 529    milanotes_acne, acnestudios, chloe, chlo\xe9, ...
# ...                                                  ...
# 24742  siambrandname, weloveshopping, somethingboudoi...
# 24744  siambrandname, weloveshopping, somethingboudoi...
# 24745  siambrandname, weloveshopping, somethingboudoi...
# 24749  siambrandname, coach, peony, zara, \u0e23\u0e3...
# 24750  siambrandname, coach, peony, zara, \u0e23\u0e3...
#
#                                                  Caption  \
# 100      u\"\"This is real and it's happening now! 00...
# 101      u\"\"This is real and it's happening now! 00...
# 120      Cute \U0001f495 #riverisland #revolveclothin...
# 121      Cute \U0001f495 #riverisland #revolveclothin...
# 529      #milanotes_acne \nAcne Studios \u2714\ufe0f ...
# ...                                                  ...
# 24742    \U0001f31f\u0e19\u0e49\u0e33\u0e2b\u0e2d\u0e...
# 24744    \U0001f31f\u0e19\u0e49\u0e33\u0e2b\u0e2d\u0e...
# 24745    \U0001f31f\u0e19\u0e49\u0e33\u0e2b\u0e2d\u0e...
# 24749    750\u0e40\u0e14\u0e23\u0e2a\u0e2a\u0e35\u0e1...
# 24750    750\u0e40\u0e14\u0e23\u0e2a\u0e2a\u0e35\u0e1...
#
#                                                   ImgURL  Likes  ...  \
# 100    https://scontent.cdninstagram.com/t51.2885-15/...     18  ...
# 101    https://scontent.cdninstagram.com/t51.2885-15/...     18  ...
# 120    https://scontent.cdninstagram.com/t51.2885-15/...    115  ...
# 121    https://scontent.cdninstagram.com/t51.2885-15/...    115  ...
# 529    https://scontent.cdninstagram.com/t51.2885-15/...     29  ...
# ...                                                  ...    ...  ...
# 24742  https://scontent.cdninstagram.com/t51.2885-15/...      0  ...
# 24744  https://scontent.cdninstagram.com/t51.2885-15/...      0  ...
# 24745  https://scontent.cdninstagram.com/t51.2885-15/...      0  ...
# 24749  https://scontent.cdninstagram.com/t51.2885-15/...      0  ...
# 24750  https://scontent.cdninstagram.com/t51.2885-15/...      0  ...
#
#        NumberOfPeople  NumberOfFashionProduct Anger  Contempt  Disgust  Fear  \
# 100          0.694253                 1.52877   0.0       0.0      0.0   0.0
# 101          0.694253                 1.52877   0.0       0.0      0.0   0.0
# 120          0.249870                 3.70682   0.0       0.0      0.0   0.0
# 121          0.249870                 3.70682   0.0       0.0      0.0   0.0
# 529          0.668240                 2.93258   0.0       0.0      0.0   0.0
# ...               ...                     ...   ...       ...      ...   ...
# 24742        0.913769                 2.19243   0.0       0.0      0.0   0.0
# 24744        0.614710                 1.28610   0.0       0.0      0.0   0.0
# 24745        0.614710                 1.28610   0.0       0.0      0.0   0.0
# 24749        0.393408                 4.05800   0.0       0.0      0.0   0.0
# 24750        0.393408                 4.05800   0.0       0.0      0.0   0.0
#
#        Happiness  Neutral  Sadness  Surprise
# 100          0.0      0.0      0.0       0.0
# 101          0.0      0.0      0.0       0.0
# 120          0.0      0.0      0.0       0.0
# 121          0.0      0.0      0.0       0.0
# 529          0.0      0.0      0.0       0.0
# ...          ...      ...      ...       ...
# 24742        0.0      0.0      0.0       0.0
# 24744        0.0      0.0      0.0       0.0
# 24745        0.0      0.0      0.0       0.0
# 24749        0.0      0.0      0.0       0.0
# 24750        0.0      0.0      0.0       0.0
#
# [1043 rows x 33 columns]

# %%
missing_values = fashiondata.isnull().sum()
print("\nMissing values:")
print(missing_values)
# Out:
# Missing values:
# UserId                      0
# Followings                  0
# Followers                   0
# MediaCount                  0
# BrandName                   0
# BrandCategory               0
# Hashtags                  146
# Caption                    35
# ImgURL                      0
# Likes                       0
# Comments                    0
# CreationTime                0
# Link                        0
# Selfie                      0
# BodySnap                    0
# Marketing                   0
# ProductOnly                 0
# NonFashion                  0
# Face                        0
# Logo                        0
# BrandLogo                   0
# Smile                       0
# Outdoor                     0
# NumberOfPeople              0
# NumberOfFashionProduct      0
# Anger                       0
# Contempt                    0
# Disgust                     0
# Fear                        0
# Happiness                   0
# Neutral                     0
# Sadness                     0
# Surprise                    0
# dtype: int64

# %% [markdown]
# When we check for duplicate rows - those duplicates are reflected in the userID and consequently the user's details, which indicates the same user may have posted multiple posts included in the dataset. For missing values, those are only present in the string variables, Hashtags and Captions, which are not the focus of our analysis. Hence, no rows/values are removed.

# %% [markdown]
# ### Aggregating datasets by unique brand category

# %%
condition = (fashiondata.dtypes == np.int64) | (fashiondata.dtypes == np.float64)
fashiondatanum = fashiondata.loc[:, condition]
print("Data dims : ", fashiondata.shape) 
fashiondatanum.info()
# Out:
# Data dims :  (24752, 33)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24752 entries, 0 to 24751
# Data columns (total 26 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Followings              24752 non-null  float64
#  1   Followers               24752 non-null  float64
#  2   MediaCount              24752 non-null  int64
#  3   Likes                   24752 non-null  int64
#  4   Comments                24752 non-null  int64
#  5   CreationTime            24752 non-null  int64
#  6   Selfie                  24752 non-null  float64
#  7   BodySnap                24752 non-null  float64
#  8   Marketing               24752 non-null  float64
#  9   ProductOnly             24752 non-null  float64
#  10  NonFashion              24752 non-null  float64
#  11  Face                    24752 non-null  float64
#  12  Logo                    24752 non-null  float64
#  13  BrandLogo               24752 non-null  float64
#  14  Smile                   24752 non-null  float64
#  15  Outdoor                 24752 non-null  float64
#  16  NumberOfPeople          24752 non-null  float64
#  17  NumberOfFashionProduct  24752 non-null  float64
#  18  Anger                   24752 non-null  float64
#  19  Contempt                24752 non-null  float64
#  20  Disgust                 24752 non-null  float64
#  21  Fear                    24752 non-null  float64
#  22  Happiness               24752 non-null  float64
#  23  Neutral                 24752 non-null  float64
#  24  Sadness                 24752 non-null  float64
#  25  Surprise                24752 non-null  float64
# dtypes: float64(22), int64(4)
# memory usage: 4.9 MB

# %%
#declaring data frames based on different values of BrandCategory
#separating BranCategory into different variable types
unique_brandcategory = fashiondata['BrandCategory'].unique()

dfs_by_brandcategory = {}

for BrandCategory in unique_brandcategory:
    dfs_by_brandcategory[BrandCategory] = fashiondata[fashiondata['BrandCategory'] == BrandCategory]

#printing to check if our separation of BrandCategory by variable worked 
for BrandCategory, df in dfs_by_brandcategory.items():
    print(f"BrandCategory: {BrandCategory}")
    print(df)
# Out:
# BrandCategory: High street
#                                UserId  Followings  Followers  MediaCount  \
# 0       1171579752855683619_212070047       518.0     9840.0         541
# 1       1171594777274371222_176762322      7333.0     2300.0         272
# 2       1171407552643586413_581125501       131.0      605.0         106
# 3       1171407552643586413_581125501       131.0      605.0         106
# 4      1171508187966229230_2797323089       132.0      456.0          56
# ...                               ...         ...        ...         ...
# 24747   1171575731978099465_389885373       459.0     3236.0        1318
# 24748   1171566570370586806_253427645       209.0     2563.0         469
# 24749  1171566525099211846_1433754542       209.0     8737.0       46254
# 24750  1171566525099211846_1433754542       209.0     8737.0       46254
# 24751   1171565778125281443_253427645       209.0     2563.0         469
#
#          BrandName BrandCategory  \
# 0      abercrombie   High street
# 1      abercrombie   High street
# 2      abercrombie   High street
# 3      abercrombie   High street
# 4      abercrombie   High street
# ...            ...           ...
# 24747         zara   High street
# 24748         zara   High street
# 24749         zara   High street
# 24750         zara   High street
# 24751         zara   High street
#
#                                                 Hashtags  \
# 0      beautiful, summer, fashion, love, cute, food, ...
# 1      teen, model, brunette, selfie, hollister, snap...
# 2      alexandani, cute, llbean, beanboots, anthropol...
# 3      alexandani, cute, llbean, beanboots, anthropol...
# 4      abercrombieandfitch, shopping, love, hollister...
# ...                                                  ...
# 24747  \u0e40\u0e2a\u0e37\u0e49\u0e2d\u0e40\u0e17\u0e...
# 24748  siambrandname, topshopthailand, somethingboudo...
# 24749  siambrandname, coach, peony, zara, \u0e23\u0e3...
# 24750  siambrandname, coach, peony, zara, \u0e23\u0e3...
# 24751  siambrandname, topshopthailand, somethingboudo...
#
#                                                  Caption  \
# 0        We were born to be REAL, not to be perfect. ...
# 1        Gotta run, but first, let me take selfie. Me...
# 2                            dress to impress\U0001f457
# 3                            dress to impress\U0001f457
# 4        #love #shopping #shoppen #hollister #abercro...
# ...                                                  ...
# 24747    \u0e41\u0e0b\u0e04\u0e41\u0e02\u0e19\u0e01\u...
# 24748    Used like new Sretsis magaret skirt sz.Us2 \...
# 24749    750\u0e40\u0e14\u0e23\u0e2a\u0e2a\u0e35\u0e1...
# 24750    750\u0e40\u0e14\u0e23\u0e2a\u0e2a\u0e35\u0e1...
# 24751    Used like new sretsis skirt sz.US.2 \u0e23\u...
#
#                                                   ImgURL  Likes  ...  \
# 0      https://scontent.cdninstagram.com/t51.2885-15/...     97  ...
# 1      https://scontent.cdninstagram.com/t51.2885-15/...     94  ...
# 2      https://scontent.cdninstagram.com/t51.2885-15/...     91  ...
# 3      https://scontent.cdninstagram.com/t51.2885-15/...     94  ...
# 4      https://scontent.cdninstagram.com/t51.2885-15/...      9  ...
# ...                                                  ...    ...  ...
# 24747  https://scontent.cdninstagram.com/t51.2885-15/...      0  ...
# 24748  https://scontent.cdninstagram.com/t51.2885-15/...      0  ...
# 24749  https://scontent.cdninstagram.com/t51.2885-15/...      0  ...
# 24750  https://scontent.cdninstagram.com/t51.2885-15/...      0  ...
# 24751  https://scontent.cdninstagram.com/t51.2885-15/...      0  ...
#
#        NumberOfPeople  NumberOfFashionProduct     Anger  Contempt   Disgust  \
# 0            0.931486                3.422110  0.083862  0.015089  0.000583
# 1            0.466329                2.919710  0.000000  0.000000  0.000000
# 2            1.116500                4.690960  0.000000  0.000000  0.000000
# 3            1.116500                4.690960  0.000000  0.000000  0.000000
# 4            0.393063                1.455860  0.000000  0.000000  0.000000
# ...               ...                     ...       ...       ...       ...
# 24747        0.226498                2.868440  0.000000  0.000000  0.000000
# 24748        0.190629                1.998940  0.000000  0.000000  0.000000
# 24749        0.393408                4.058000  0.000000  0.000000  0.000000
# 24750        0.393408                4.058000  0.000000  0.000000  0.000000
# 24751        0.043583                0.866115  0.000000  0.000000  0.000000
#
#            Fear  Happiness   Neutral   Sadness  Surprise
# 0      0.000026   0.000017  0.890586  0.009657  0.000181
# 1      0.000000   0.000000  0.000000  0.000000  0.000000
# 2      0.000000   0.000000  0.000000  0.000000  0.000000
# 3      0.000000   0.000000  0.000000  0.000000  0.000000
# 4      0.000000   0.000000  0.000000  0.000000  0.000000
# ...         ...        ...       ...       ...       ...
# 24747  0.000000   0.000000  0.000000  0.000000  0.000000
# 24748  0.000000   0.000000  0.000000  0.000000  0.000000
# 24749  0.000000   0.000000  0.000000  0.000000  0.000000
# 24750  0.000000   0.000000  0.000000  0.000000  0.000000
# 24751  0.000000   0.000000  0.000000  0.000000  0.000000
#
# [5773 rows x 33 columns]
# BrandCategory: Designer
#                                UserId  Followings  Followers  MediaCount  \
# 128      1170965614629611621_42873193         3.0   272802.0        8003
# 129    1170962625233505754_1434569946        70.0    34489.0         504
# 130    1171566784018271168_1629130913       194.0     2008.0         978
# 131    1171198884226397415_1463767428      1407.0     4087.0        2791
# 132       1170731183936702992_9745321    127684.0    24532.0        3649
# ...                               ...         ...        ...         ...
# 24202  1169997302480808669_2092220553         5.0       78.0         295
# 24203  1171308884169047663_2802317542       395.0      140.0         704
# 24204   1170482237147791967_559781615       362.0      119.0          77
# 24205   1170481417463349832_559781615       362.0      119.0          77
# 24206    1170004908468721953_22393957        28.0       22.0          68
#
#               BrandName BrandCategory  \
# 128         acnestudios      Designer
# 129         acnestudios      Designer
# 130         acnestudios      Designer
# 131         acnestudios      Designer
# 132         acnestudios      Designer
# ...                 ...           ...
# 24202  viviennewestwood      Designer
# 24203  viviennewestwood      Designer
# 24204  viviennewestwood      Designer
# 24205  viviennewestwood      Designer
# 24206  viviennewestwood      Designer
#
#                                                 Hashtags  \
# 128         acne, acnestudios, 16ss, campaign, editor_ys
# 129    acnestudios, auralee, acne, celinebambam, fend...
# 130    loversandfriends, help, wiwt, acnestudios, isa...
# 131    supreme, fashion, streetart, clothingline, bea...
# 132    hsdailyfeature, fearofgodla, yeezyseason, stre...
# ...                                                  ...
# 24202  \u30f4\u30a3\u30f4\u30a3\u30a2\u30f3\u30a6\u30...
# 24203             maisonmartinmargiela, viviennewestwood
# 24204                                   viviennewestwood
# 24205                                   viviennewestwood
# 24206                                   viviennewestwood
#
#                                                  Caption  \
# 128      u\"\"\uad6d\ub0b4\uc5d0\uc11c \ub354\ube14\u...
# 129      \u4eca\u65e5\u306e\u30b3\u30fc\u30c7\u3002\n...
# 130      Today I need some help \U0001f477\U0001f3fd\...
# 131      #fashion #screenprinting #beauty #clothingli...
# 132      u\"\"+Flannel Oversized Raglan Baseball Jers...
# ...                                                  ...
# 24202    225\n226\n\n#viviennewestwood \n#viviennewes...
# 24203    Vogue Italia January 2012 | Like A Doll by T...
# 24204                                 #viviennewestwood
# 24205                                 #viviennewestwood
# 24206     One of my favourite brands\n#VivienneWestwood
#
#                                                   ImgURL  Likes  ...  \
# 128    https://scontent.cdninstagram.com/t51.2885-15/...    990  ...
# 129    https://scontent.cdninstagram.com/t51.2885-15/...    990  ...
# 130    https://scontent.cdninstagram.com/t51.2885-15/...     98  ...
# 131    https://scontent.cdninstagram.com/t51.2885-15/...     98  ...
# 132    https://scontent.cdninstagram.com/t51.2885-15/...     98  ...
# ...                                                  ...    ...  ...
# 24202  https://scontent.cdninstagram.com/t51.2885-15/...     10  ...
# 24203  https://scontent.cdninstagram.com/t51.2885-15/...      1  ...
# 24204  https://scontent.cdninstagram.com/t51.2885-15/...      1  ...
# 24205  https://scontent.cdninstagram.com/t51.2885-15/...      1  ...
# 24206  https://scontent.cdninstagram.com/t51.2885-15/...      1  ...
#
#        NumberOfPeople  NumberOfFashionProduct     Anger  Contempt   Disgust  \
# 128          1.384500                2.543530  0.007987  0.101104  0.004442
# 129          0.813016                5.107610  0.000000  0.000000  0.000000
# 130          0.406707                1.461270  0.000000  0.000000  0.000000
# 131          0.313150                0.919634  0.000000  0.000000  0.000000
# 132          0.653134                4.837520  0.000000  0.000000  0.000000
# ...               ...                     ...       ...       ...       ...
# 24202        0.243162                2.288850  0.000000  0.000000  0.000000
# 24203        2.067420                5.522950  0.000000  0.000000  0.000000
# 24204        2.200710                4.741380  0.000000  0.000000  0.000000
# 24205        2.364730                4.766110  0.000000  0.000000  0.000000
# 24206        1.335700                2.342150  0.000000  0.000000  0.000000
#
#            Fear  Happiness   Neutral   Sadness  Surprise
# 128    0.000149   0.016795  0.848112  0.020275  0.001135
# 129    0.000000   0.000000  0.000000  0.000000  0.000000
# 130    0.000000   0.000000  0.000000  0.000000  0.000000
# 131    0.000000   0.000000  0.000000  0.000000  0.000000
# 132    0.000000   0.000000  0.000000  0.000000  0.000000
# ...         ...        ...       ...       ...       ...
# 24202  0.000000   0.000000  0.000000  0.000000  0.000000
# 24203  0.000000   0.000000  0.000000  0.000000  0.000000
# 24204  0.000000   0.000000  0.000000  0.000000  0.000000
# 24205  0.000000   0.000000  0.000000  0.000000  0.000000
# 24206  0.000000   0.000000  0.000000  0.000000  0.000000
#
# [11086 rows x 33 columns]
# BrandCategory: Small couture
#                                UserId  Followings  Followers  MediaCount  \
# 2816     1166049095937320998_51510153      1632.0    28021.0        2053
# 2817     1168383557155640843_14917772      1480.0     1541.0        1042
# 2818   1168947444483649147_1452755794      7411.0     5980.0        1874
# 2819    1168218659769612190_855515828       552.0     5556.0        3415
# 2820    1168216405213771594_855515828       552.0     5556.0        3415
# ...                               ...         ...        ...         ...
# 17733  1167813025450919547_1587541248        32.0       63.0         664
# 17734  1092461517296104915_2211443580       997.0      529.0         151
# 17735  1030712545293425455_2139434149        18.0       31.0          23
# 17736  1019836187233805265_1901017615       773.0      301.0         362
# 17737  1143380879625913947_1587541248        32.0       63.0         664
#
#            BrandName  BrandCategory  \
# 2816          brioni  Small couture
# 2817          brioni  Small couture
# 2818          brioni  Small couture
# 2819          brioni  Small couture
# 2820          brioni  Small couture
# ...              ...            ...
# 17733  nancygonzalez  Small couture
# 17734  nancygonzalez  Small couture
# 17735  nancygonzalez  Small couture
# 17736  nancygonzalez  Small couture
# 17737  nancygonzalez  Small couture
#
#                                                 Hashtags  \
# 2816   mfwaw16, fashion, fw16, successmen, fashionsho...
# 2817   supreme, brioni, ootd, hans, saintlaurent, raf...
# 2818   andytauer, biehlparfumkunstwerke, asgharali, a...
# 2819   \u0440\u0435\u043c\u043d\u0438, etro, valetinn...
# 2820   \u0440\u0435\u043c\u043d\u0438, etro, valetinn...
# ...                                                  ...
# 17733                                      nancygonzalez
# 17734                                mama, nancygonzalez
# 17735  style, fashion, polyvore, ki, roksanda, fraule...
# 17736  flowerpower, indianflowers, nancygonzalez, repost
# 17737                                      nancygonzalez
#
#                                                  Caption  \
# 2816     @thorbengartner @mikkelgjensen @gatesboyd an...
# 2817     u\"\"Headless warrior #ootd looks [Edit: wai...
# 2818     \u0423 \u043d\u0430\u0441 \u0435\u0441\u0442...
# 2819     DOLCE & GABBANA  \u041f\u043e \u0432\u0441\u...
# 2820     ICEBERG  \u041f\u043e \u0432\u0441\u0435\u04...
# ...                                                  ...
# 17733                                    #nancygonzalez
# 17734                  Feliz noche #mama #NancyGonzalez
# 17735    #frauleindoyin #Untitled41 @polyvore #polyvo...
# 17736    #Repost @bat_gio with @repostapp.\n\u30fb\u3...
# 17737                                    #nancygonzalez
#
#                                                   ImgURL  Likes  ...  \
# 2816   https://scontent.cdninstagram.com/t51.2885-15/...     99  ...
# 2817   https://scontent.cdninstagram.com/t51.2885-15/...     94  ...
# 2818   https://scontent.cdninstagram.com/t51.2885-15/...      9  ...
# 2819   https://scontent.cdninstagram.com/t51.2885-15/...      9  ...
# 2820   https://scontent.cdninstagram.com/t51.2885-15/...      9  ...
# ...                                                  ...    ...  ...
# 17733  https://scontent.cdninstagram.com/hphotos-xpa1...      1  ...
# 17734  https://scontent.cdninstagram.com/hphotos-xta1...      1  ...
# 17735  https://scontent.cdninstagram.com/hphotos-xap1...      1  ...
# 17736  https://scontent.cdninstagram.com/hphotos-xfp1...      1  ...
# 17737  https://scontent.cdninstagram.com/hphotos-xfp1...      0  ...
#
#        NumberOfPeople  NumberOfFashionProduct     Anger  Contempt   Disgust  \
# 2816         2.517010                 7.17593  0.015043  0.001643  0.000156
# 2817         0.655850                 5.28884  0.000000  0.000000  0.000000
# 2818         0.230777                 1.30213  0.000000  0.000000  0.000000
# 2819         0.499740                 5.51109  0.000000  0.000000  0.000000
# 2820         0.494691                 4.47698  0.000000  0.000000  0.000000
# ...               ...                     ...       ...       ...       ...
# 17733        0.154729                 1.52868  0.000000  0.000000  0.000000
# 17734        2.094150                 3.70689  0.000000  0.000000  0.000000
# 17735        0.439105                 2.87585  0.000000  0.000000  0.000000
# 17736        0.159309                 1.95113  0.000000  0.000000  0.000000
# 17737        0.169526                 1.54674  0.000000  0.000000  0.000000
#
#            Fear  Happiness   Neutral  Sadness  Surprise
# 2816   0.000005   0.000008  0.976946  0.00616   0.00004
# 2817   0.000000   0.000000  0.000000  0.00000   0.00000
# 2818   0.000000   0.000000  0.000000  0.00000   0.00000
# 2819   0.000000   0.000000  0.000000  0.00000   0.00000
# 2820   0.000000   0.000000  0.000000  0.00000   0.00000
# ...         ...        ...       ...      ...       ...
# 17733  0.000000   0.000000  0.000000  0.00000   0.00000
# 17734  0.000000   0.000000  0.000000  0.00000   0.00000
# 17735  0.000000   0.000000  0.000000  0.00000   0.00000
# 17736  0.000000   0.000000  0.000000  0.00000   0.00000
# 17737  0.000000   0.000000  0.000000  0.00000   0.00000
#
# [6036 rows x 33 columns]
# BrandCategory: Mega couture
#                                UserId  Followings  Followers  MediaCount  \
# 4223     1171417489671904317_54806206      7224.0    54073.0        2867
# 4224    1171419567772687797_936955534       652.0     6486.0        1035
# 4225    1171486410025470247_516169353      4017.0     2280.0       12751
# 4226    1171485888245664033_516169353      4017.0     2280.0       12751
# 4227    1171482600238483698_516169353      4017.0     2280.0       12751
# ...                               ...         ...        ...         ...
# 21179  1171447244142961576_1370989119        75.0      297.0        1141
# 21180  1171439442734359760_2358471032        52.0      322.0        1308
# 21181  1171425623953822429_2080570947         7.0       39.0          99
# 21182  1171419698383000662_2654945228        63.0       12.0           4
# 21183  1171441039038278567_2372693129        22.0     3118.0        1164
#
#       BrandName BrandCategory  \
# 4223   burberry  Mega couture
# 4224   burberry  Mega couture
# 4225   burberry  Mega couture
# 4226   burberry  Mega couture
# 4227   burberry  Mega couture
# ...         ...           ...
# 21179   tiffany  Mega couture
# 21180   tiffany  Mega couture
# 21181   tiffany  Mega couture
# 21182   tiffany  Mega couture
# 21183   tiffany  Mega couture
#
#                                                 Hashtags  \
# 4223   beautiful, burberry, fashion, spectacular, awe...
# 4224   burberry, classic, winteroutfits, streetfashio...
# 4225   ck, burberry, creed, jomalonelondon, dkny, est...
# 4226   ck, burberry, creed, jomalonelondon, dkny, est...
# 4227   ck, burberry, creed, jomalonelondon, dkny, est...
# ...                                                  ...
# 21179  tiffanyhwang, tiffany, girlsgeneration, kimtae...
# 21180  teamtolayts, tiffany, tiffalyts, nicstersofc, ...
# 21181  beautiful, gift, earrings, tiffany, forsale, v...
# 21182                           tiffany, girlsgeneration
# 21183                                            tiffany
#
#                                                  Caption  \
# 4223     \u30fb\u30fb\u30fb\n#burberry #burberryprors...
# 4224     No matter what you are wearing, wear it with...
# 4225     \U0001f4dd\u0e2a\u0e19\u0e43\u0e08\u0e2a\u0e...
# 4226     \U0001f4dd\u0e2a\u0e19\u0e43\u0e08\u0e2a\u0e...
# 4227     \U0001f4dd\u0e2a\u0e19\u0e43\u0e08\u0e2a\u0e...
# ...                                                  ...
# 21179    Meghan Trainor mentioned our Taeny \U0001f60...
# 21180    u\"\"UPDATE: Kuya Nico's IG\n\nTolayts at Ti...
# 21181    #forsale #tiffany #sterlingsilver #earrings ...
# 21182      Unnie \U0001f495\n#tiffany\n#girlsgeneration
# 21183    sexy back!!! \u2764\ufe0f #tiffany \U0001f4f...
#
#                                                   ImgURL  Likes  ...  \
# 4223   https://scontent.cdninstagram.com/t51.2885-15/...     96  ...
# 4224   https://scontent.cdninstagram.com/t51.2885-15/...     90  ...
# 4225   https://scontent.cdninstagram.com/t51.2885-15/...      9  ...
# 4226   https://scontent.cdninstagram.com/t51.2885-15/...      9  ...
# 4227   https://scontent.cdninstagram.com/t51.2885-15/...      9  ...
# ...                                                  ...    ...  ...
# 21179  https://scontent.cdninstagram.com/t51.2885-15/...      1  ...
# 21180  https://scontent.cdninstagram.com/t51.2885-15/...      1  ...
# 21181  https://scontent.cdninstagram.com/t51.2885-15/...      1  ...
# 21182  https://scontent.cdninstagram.com/t51.2885-15/...      1  ...
# 21183  https://scontent.cdninstagram.com/t51.2885-15/...      0  ...
#
#        NumberOfPeople  NumberOfFashionProduct         Anger      Contempt  \
# 4223         2.514700                3.229100  5.050000e-07  4.360000e-09
# 4224         2.052310                5.309000  0.000000e+00  0.000000e+00
# 4225         0.383649                1.925920  0.000000e+00  0.000000e+00
# 4226         0.278845                2.481410  0.000000e+00  0.000000e+00
# 4227         0.277149                0.527519  0.000000e+00  0.000000e+00
# ...               ...                     ...           ...           ...
# 21179        0.678471                1.840990  0.000000e+00  0.000000e+00
# 21180        2.165740                4.005500  0.000000e+00  0.000000e+00
# 21181        0.141749                1.704310  0.000000e+00  0.000000e+00
# 21182        2.062720                2.484290  0.000000e+00  0.000000e+00
# 21183        1.712300                5.193790  0.000000e+00  0.000000e+00
#
#             Disgust          Fear  Happiness       Neutral       Sadness  \
# 4223   8.650000e-08  3.230000e-10   0.999999  6.050000e-08  4.300000e-08
# 4224   0.000000e+00  0.000000e+00   0.000000  0.000000e+00  0.000000e+00
# 4225   0.000000e+00  0.000000e+00   0.000000  0.000000e+00  0.000000e+00
# 4226   0.000000e+00  0.000000e+00   0.000000  0.000000e+00  0.000000e+00
# 4227   0.000000e+00  0.000000e+00   0.000000  0.000000e+00  0.000000e+00
# ...             ...           ...        ...           ...           ...
# 21179  0.000000e+00  0.000000e+00   0.000000  0.000000e+00  0.000000e+00
# 21180  0.000000e+00  0.000000e+00   0.000000  0.000000e+00  0.000000e+00
# 21181  0.000000e+00  0.000000e+00   0.000000  0.000000e+00  0.000000e+00
# 21182  0.000000e+00  0.000000e+00   0.000000  0.000000e+00  0.000000e+00
# 21183  0.000000e+00  0.000000e+00   0.000000  0.000000e+00  0.000000e+00
#
#            Surprise
# 4223   2.020000e-08
# 4224   0.000000e+00
# 4225   0.000000e+00
# 4226   0.000000e+00
# 4227   0.000000e+00
# ...             ...
# 21179  0.000000e+00
# 21180  0.000000e+00
# 21181  0.000000e+00
# 21182  0.000000e+00
# 21183  0.000000e+00
#
# [1857 rows x 33 columns]

# %% [markdown]
# Our aim is to analyze characteristics of a well-performing social media fashion post for each tier of brand category hence aggregating brands of a certain brand category and their subsequent posts to separate datasets.

# %% [markdown]
#  ### Function to remove outliers

# %%
# Function to remove outliers using IQR
def remove_outliers(df):
    Q1 = df.quantile(0.25)
    Q3 = df.quantile(0.75)
    IQR = Q3 - Q1
    return df[~((df < (Q1 - 1.5 * IQR)) | (df > (Q3 + 1.5 * IQR))).any(axis=1)]

# %% [markdown]
# ### Segregating numeric variable by each brand category and use the dtype filter to extract the numeric data

# %%
dfs_wo_outliers = {}
for category in unique_brandcategory:
    category_data = dfs_by_brandcategory[category]
    numeric_data = category_data.select_dtypes(include=[np.number])  # Ensure only numeric data is considered
    cleaned_data = remove_outliers(numeric_data)  # Remove outliers from numeric data
    dfs_wo_outliers[category] = cleaned_data  # Compute and store correlations

# %% [markdown]
# ### Creating dataframes based on each brand category pre and post outlier removal

# %%
# Load the CSV files into a DataFrame
highstreetnum.to_csv('highstreetnum.csv')
designernum.to_csv('designernum.csv')
megacouturenum.to_csv('megacouturenum.csv')
smallcouturenum.to_csv('smallcouturenum.csv')

# %%
# Load the CSV files (cleaned ones) into a DataFrame
dfs_wo_outliers['High street'].to_csv('highstreetnum_wo_outliers.csv')
dfs_wo_outliers['Designer'].to_csv('designernum_wo_outliers.csv')
dfs_wo_outliers['Mega couture'].to_csv('megacouturenum_wo_outliers.csv')
dfs_wo_outliers['Small couture'].to_csv('smallcouturenum_wo_outliers.csv')
